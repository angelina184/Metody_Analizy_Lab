# %%
import pandas as pd
import os
DATAPATH = 'C:\\anal_danych\\Labs\\swps-metody-analizy-danych\\lab_05\\data'
df = pd.read_csv(os.path.join(DATAPATH, 'loan_data.csv'))

# %% [markdown]
# 1. Zamień nazwę kolumny `loan_amnt` na `loan_amount`.

# %%
df.rename(columns={'loan_amnt': 'loan_amount'}, inplace=True)
df.columns
# Out:
# Index(['person_age', 'person_gender', 'person_education', 'person_income',
#        'person_emp_exp', 'person_home_ownership', 'loan_amount', 'loan_intent',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score', 'previous_loan_defaults_on_file', 'loan_status'],
#       dtype='object')

# %% [markdown]
# 2. Z ramki danych wykorzystanej w przykładach (loan) wyświetl:
# * a) tylko kolumny 'person_gender', 'person_age' oraz 'person_income',
# * b) wiersze od 1000 do 2000 włącznie (chodzi o kolejne wiersze w ramce, a nie wartość indeksu),
# * c) wiersze parzyste,
# * d) wiersze o parzystej wartości w kolumnie indeks,
# * e) pierwszą i ostatnią kolumnę.

# %%
#a)
# df['person_gender']
# df['person_age']
# df['person_income']

# col_names = list(df.columns)
# result = col_names[1:2] + col_names[0:1] + col_names[3:4]
# print(result) #['person_gender', 'person_age', 'person_income']
# a = df.loc[:,result]
# a.head()

#df.iloc[:, [1,0,3]]
# Out:
#       person_gender  person_age  person_income
# 0            female        22.0        71948.0
# 1            female        21.0        12282.0
# 2            female        25.0        12438.0
# 3            female        23.0        79753.0
# 4              male        24.0        66135.0
# ...             ...         ...            ...
# 44995          male        27.0        47971.0
# 44996        female        37.0        65800.0
# 44997          male        33.0        56942.0
# 44998          male        29.0        33164.0
# 44999          male        24.0        51609.0
#
# [45000 rows x 3 columns]

# %%
#b)
df.iloc[1000:2001]
# Out:
#       person_age person_gender person_education  person_income  \
# 1000        23.0          male         Bachelor        30059.0
# 1001        24.0          male         Bachelor        68258.0
# 1002        21.0          male         Bachelor        60821.0
# 1003        25.0          male      High School        70432.0
# 1004        21.0        female         Bachelor        63842.0
# ...          ...           ...              ...            ...
# 1996        21.0          male           Master        37264.0
# 1997        24.0        female        Associate        36841.0
# 1998        24.0          male         Bachelor        37068.0
# 1999        22.0          male         Bachelor        37513.0
# 2000        23.0        female        Associate        36711.0
#
#       person_emp_exp person_home_ownership  loan_amount        loan_intent  \
# 1000               0              MORTGAGE       1375.0            MEDICAL
# 1001               2                  RENT      18000.0          EDUCATION
# 1002               0                  RENT      18000.0          EDUCATION
# 1003               6                  RENT      18000.0            VENTURE
# 1004               0                  RENT      18000.0            MEDICAL
# ...              ...                   ...          ...                ...
# 1996               0                  RENT      14000.0            MEDICAL
# 1997               4                  RENT      14000.0  DEBTCONSOLIDATION
# 1998               2              MORTGAGE       3075.0  DEBTCONSOLIDATION
# 1999               0                  RENT      14000.0            VENTURE
# 2000               0                  RENT      14000.0            MEDICAL
#
#       loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1000          11.11                 0.05                         4.0
# 1001          13.48                 0.26                         3.0
# 1002          14.74                 0.30                         2.0
# 1003          11.01                 0.26                         4.0
# 1004          19.69                 0.28                         2.0
# ...             ...                  ...                         ...
# 1996          10.65                 0.38                         2.0
# 1997           7.90                 0.38                         2.0
# 1998          11.01                 0.08                         4.0
# 1999           6.99                 0.37                         4.0
# 2000          11.26                 0.38                         3.0
#
#       credit_score previous_loan_defaults_on_file  loan_status
# 1000           506                             No            1
# 1001           671                             No            1
# 1002           530                             No            1
# 1003           609                             No            1
# 1004           678                             No            1
# ...            ...                            ...          ...
# 1996           545                             No            1
# 1997           538                             No            1
# 1998           521                            Yes            0
# 1999           595                             No            1
# 2000           554                             No            1
#
# [1001 rows x 14 columns]

# %%
#c)wiersze parzyste
print(df.index)
df.iloc[::2]
# Out:
# RangeIndex(start=0, stop=45000, step=1)
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 2            25.0        female      High School        12438.0
# 4            24.0          male           Master        66135.0
# 6            26.0        female         Bachelor        93471.0
# 8            24.0        female        Associate       100684.0
# ...           ...           ...              ...            ...
# 44990        31.0          male           Master       136832.0
# 44992        23.0        female         Bachelor        40925.0
# 44994        24.0        female        Associate        31924.0
# 44996        37.0        female        Associate        65800.0
# 44998        29.0          male         Bachelor        33164.0
#
#        person_emp_exp person_home_ownership  loan_amount      loan_intent  \
# 0                   0                  RENT      35000.0         PERSONAL
# 2                   3              MORTGAGE       5500.0          MEDICAL
# 4                   1                  RENT      35000.0          MEDICAL
# 6                   1                  RENT      35000.0        EDUCATION
# 8                   3                  RENT      35000.0         PERSONAL
# ...               ...                   ...          ...              ...
# 44990               9                  RENT      12319.0         PERSONAL
# 44992               0                  RENT       9000.0         PERSONAL
# 44994               2                  RENT      12229.0          MEDICAL
# 44996              17                  RENT       9000.0  HOMEIMPROVEMENT
# 44998               4                  RENT      12000.0        EDUCATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 2              12.87                 0.44                         3.0
# 4              14.27                 0.53                         4.0
# 6              12.42                 0.37                         3.0
# 8               8.90                 0.35                         2.0
# ...              ...                  ...                         ...
# 44990          16.92                 0.09                         7.0
# 44992          11.01                 0.22                         4.0
# 44994          10.70                 0.38                         4.0
# 44996          14.07                 0.14                        11.0
# 44998          13.23                 0.36                         6.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 2               635                             No            1
# 4               586                             No            1
# 6               701                             No            1
# 8               544                             No            1
# ...             ...                            ...          ...
# 44990           722                             No            1
# 44992           487                             No            1
# 44994           678                             No            1
# 44996           621                             No            1
# 44998           604                             No            1
#
# [22500 rows x 14 columns]

# %%
#d)wiersze o parzystej wartości w kolumnie indeks
df.loc[df.index %2 == 0]
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 2            25.0        female      High School        12438.0
# 4            24.0          male           Master        66135.0
# 6            26.0        female         Bachelor        93471.0
# 8            24.0        female        Associate       100684.0
# ...           ...           ...              ...            ...
# 44990        31.0          male           Master       136832.0
# 44992        23.0        female         Bachelor        40925.0
# 44994        24.0        female        Associate        31924.0
# 44996        37.0        female        Associate        65800.0
# 44998        29.0          male         Bachelor        33164.0
#
#        person_emp_exp person_home_ownership  loan_amount      loan_intent  \
# 0                   0                  RENT      35000.0         PERSONAL
# 2                   3              MORTGAGE       5500.0          MEDICAL
# 4                   1                  RENT      35000.0          MEDICAL
# 6                   1                  RENT      35000.0        EDUCATION
# 8                   3                  RENT      35000.0         PERSONAL
# ...               ...                   ...          ...              ...
# 44990               9                  RENT      12319.0         PERSONAL
# 44992               0                  RENT       9000.0         PERSONAL
# 44994               2                  RENT      12229.0          MEDICAL
# 44996              17                  RENT       9000.0  HOMEIMPROVEMENT
# 44998               4                  RENT      12000.0        EDUCATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 2              12.87                 0.44                         3.0
# 4              14.27                 0.53                         4.0
# 6              12.42                 0.37                         3.0
# 8               8.90                 0.35                         2.0
# ...              ...                  ...                         ...
# 44990          16.92                 0.09                         7.0
# 44992          11.01                 0.22                         4.0
# 44994          10.70                 0.38                         4.0
# 44996          14.07                 0.14                        11.0
# 44998          13.23                 0.36                         6.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 2               635                             No            1
# 4               586                             No            1
# 6               701                             No            1
# 8               544                             No            1
# ...             ...                            ...          ...
# 44990           722                             No            1
# 44992           487                             No            1
# 44994           678                             No            1
# 44996           621                             No            1
# 44998           604                             No            1
#
# [22500 rows x 14 columns]

# %%
#e) pierwszą i ostatnią kolumnę.
df.iloc[:,[0,-1]]
# Out:
#        person_age  loan_status
# 0            22.0            1
# 1            21.0            0
# 2            25.0            1
# 3            23.0            1
# 4            24.0            1
# ...           ...          ...
# 44995        27.0            1
# 44996        37.0            1
# 44997        33.0            1
# 44998        29.0            1
# 44999        24.0            1
#
# [45000 rows x 2 columns]

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amount        loan_intent  \
# 0                   0                  RENT      35000.0           PERSONAL
# 1                   0                   OWN       1000.0          EDUCATION
# 2                   3              MORTGAGE       5500.0            MEDICAL
# 3                   0                  RENT      35000.0            MEDICAL
# 4                   1                  RENT      35000.0            MEDICAL
# ...               ...                   ...          ...                ...
# 44995               6                  RENT      15000.0            MEDICAL
# 44996              17                  RENT       9000.0    HOMEIMPROVEMENT
# 44997               7                  RENT       2771.0  DEBTCONSOLIDATION
# 44998               4                  RENT      12000.0          EDUCATION
# 44999               1                  RENT       6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 1              11.14                 0.08                         2.0
# 2              12.87                 0.44                         3.0
# 3              15.23                 0.44                         2.0
# 4              14.27                 0.53                         4.0
# ...              ...                  ...                         ...
# 44995          15.66                 0.31                         3.0
# 44996          14.07                 0.14                        11.0
# 44997          10.02                 0.05                        10.0
# 44998          13.23                 0.36                         6.0
# 44999          17.05                 0.13                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 1               504                            Yes            0
# 2               635                             No            1
# 3               675                             No            1
# 4               586                             No            1
# ...             ...                            ...          ...
# 44995           645                             No            1
# 44996           621                             No            1
# 44997           668                             No            1
# 44998           604                             No            1
# 44999           628                             No            1
#
# [45000 rows x 14 columns]

# %% [markdown]
# 3. Z tej samej ramki danych wyświetl dane wykorzystując filtry oparte o mapowanie:
# * a) tylko kobiety z wykształceniem 'Master' oraz 'Bachelor' i pożyczkami pomiędzy 50000 a 70000,
# * b) wszyscy mężczyźni z wykształceniem innym niż 'Master' oraz będący właścicielem lokalu (kolumna person_home_ownership = OWN),
# * c) wszystkie osoby z wartością `loan_percent_income` w przedziale od 0.4 do 0.6,
# * d) wszystkie wartości pożyczek, których kwota jest wielokrotnością liczby 10000.

# %%
#a)
print("Max loan amount:", df['loan_amount'].max())
df[((df['loan_amount'] > 5_000) & (df['loan_amount'] < 7_000)) & (df['person_gender'] == 'female') & (df['person_education'].isin([ "Master", "Bachelor"]))]
# Out:
# Max loan amount: 35000.0
#        person_age person_gender person_education  person_income  \
# 715          24.0        female         Bachelor        25826.0
# 731          26.0        female         Bachelor        26792.0
# 799          25.0        female         Bachelor        27570.0
# 915          25.0        female         Bachelor        29498.0
# 950          25.0        female         Bachelor        29750.0
# ...           ...           ...              ...            ...
# 44780        25.0        female         Bachelor        71016.0
# 44814        33.0        female         Bachelor        44496.0
# 44888        23.0        female         Bachelor        41805.0
# 44901        25.0        female         Bachelor        24049.0
# 44963        26.0        female         Bachelor        42960.0
#
#        person_emp_exp person_home_ownership  loan_amount        loan_intent  \
# 715                 4                 OTHER       6000.0           PERSONAL
# 731                 4                   OWN       5200.0          EDUCATION
# 799                 0              MORTGAGE       5875.0          EDUCATION
# 915                 6              MORTGAGE       6000.0            MEDICAL
# 950                 0              MORTGAGE       5800.0  DEBTCONSOLIDATION
# ...               ...                   ...          ...                ...
# 44780               5                  RENT       5578.0            MEDICAL
# 44814              12                  RENT       5610.0    HOMEIMPROVEMENT
# 44888               0                  RENT       6497.0  DEBTCONSOLIDATION
# 44901               0                  RENT       5937.0    HOMEIMPROVEMENT
# 44963               5                  RENT       6380.0            MEDICAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 715            12.21                 0.23                         2.0
# 731            12.42                 0.19                         3.0
# 799             6.62                 0.21                         2.0
# 915            14.59                 0.20                         2.0
# 950             5.99                 0.19                         3.0
# ...              ...                  ...                         ...
# 44780          14.36                 0.08                         4.0
# 44814          11.98                 0.13                         7.0
# 44888          13.23                 0.16                         4.0
# 44901          12.38                 0.25                         3.0
# 44963          15.95                 0.15                         6.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 715             655                             No            0
# 731             674                             No            0
# 799             680                             No            1
# 915             664                             No            1
# 950             639                             No            0
# ...             ...                            ...          ...
# 44780           672                             No            1
# 44814           687                             No            1
# 44888           635                             No            1
# 44901           675                             No            1
# 44963           686                             No            1
#
# [1077 rows x 14 columns]

# %%
#b)wszyscy mężczyźni z wykształceniem innym niż 'Master' oraz będący właścicielem lokalu (kolumna person_home_ownership = OWN),
df.query("person_education != 'Master' and person_gender == 'male' and person_home_ownership == 'OWN'")
# Out:
#        person_age person_gender person_education  person_income  \
# 27           23.0          male      High School        14293.0
# 30           21.0          male      High School        14858.0
# 35           21.0          male        Associate        15150.0
# 43           23.0          male      High School       361547.0
# 57           23.0          male         Bachelor       333399.0
# ...           ...           ...              ...            ...
# 44353        25.0          male      High School        18772.0
# 44391        26.0          male        Associate        15288.0
# 44543        30.0          male      High School        24052.0
# 44683        23.0          male        Associate        23346.0
# 44825        22.0          male      High School        22538.0
#
#        person_emp_exp person_home_ownership  loan_amount      loan_intent  \
# 27                  0                   OWN       1400.0         PERSONAL
# 30                  0                   OWN       2000.0          MEDICAL
# 35                  0                   OWN       2500.0        EDUCATION
# 43                  0                   OWN      24250.0        EDUCATION
# 57                  1                   OWN      35000.0         PERSONAL
# ...               ...                   ...          ...              ...
# 44353               2                   OWN       4468.0          VENTURE
# 44391               2                   OWN       2690.0        EDUCATION
# 44543               8                   OWN       7000.0  HOMEIMPROVEMENT
# 44683               2                   OWN       4027.0          VENTURE
# 44825               1                   OWN       4913.0        EDUCATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 27              9.32                 0.10                         3.0
# 30             11.12                 0.13                         3.0
# 35              7.51                 0.17                         4.0
# 43             19.41                 0.07                         2.0
# 57             11.01                 0.10                         4.0
# ...              ...                  ...                         ...
# 44353          11.99                 0.24                         4.0
# 44391          10.96                 0.18                         4.0
# 44543          15.78                 0.29                         5.0
# 44683          15.01                 0.17                         4.0
# 44825          13.68                 0.22                         5.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 27              607                             No            0
# 30              589                             No            1
# 35              600                             No            1
# 43              637                            Yes            0
# 57              609                             No            0
# ...             ...                            ...          ...
# 44353           658                             No            1
# 44391           649                             No            1
# 44543           590                             No            1
# 44683           646                             No            1
# 44825           637                             No            1
#
# [1360 rows x 14 columns]

# %%
#c) wszystkie osoby z wartością `loan_percent_income` w przedziale od 0.4 do 0.6,
df.query("loan_percent_income >= 0.4 and loan_percent_income <= 0.6")
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# 22           22.0        female           Master        79255.0
# ...           ...           ...              ...            ...
# 44903        25.0          male        Associate        43219.0
# 44940        29.0          male      High School        30046.0
# 44942        27.0          male           Master        48432.0
# 44966        26.0        female         Bachelor        36844.0
# 44986        34.0          male         Bachelor        41876.0
#
#        person_emp_exp person_home_ownership  loan_amount        loan_intent  \
# 0                   0                  RENT      35000.0           PERSONAL
# 2                   3              MORTGAGE       5500.0            MEDICAL
# 3                   0                  RENT      35000.0            MEDICAL
# 4                   1                  RENT      35000.0            MEDICAL
# 22                  0                  RENT      34000.0          EDUCATION
# ...               ...                   ...          ...                ...
# 44903               1                  RENT      22807.0            MEDICAL
# 44940               7                  RENT      12092.0           PERSONAL
# 44942               8                  RENT      20223.0            VENTURE
# 44966               0                  RENT      16000.0  DEBTCONSOLIDATION
# 44986              14                  RENT      19594.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 2              12.87                 0.44                         3.0
# 3              15.23                 0.44                         2.0
# 4              14.27                 0.53                         4.0
# 22             17.58                 0.43                         4.0
# ...              ...                  ...                         ...
# 44903          12.67                 0.53                         5.0
# 44940          11.79                 0.40                         7.0
# 44942           6.83                 0.42                         8.0
# 44966          12.00                 0.43                         5.0
# 44986          12.03                 0.47                         8.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 2               635                             No            1
# 3               675                             No            1
# 4               586                             No            1
# 22              691                             No            1
# ...             ...                            ...          ...
# 44903           668                             No            1
# 44940           535                             No            1
# 44942           650                             No            1
# 44966           620                             No            1
# 44986           707                             No            1
#
# [508 rows x 14 columns]

# %%
#d) wszystkie wartości pożyczek, których kwota jest wielokrotnością liczby 10000.
df.query("loan_amount % 10000 == 0")
# Out:
#        person_age person_gender person_education  person_income  \
# 15           23.0        female           Master       600891.0
# 36           22.0        female         Bachelor        58868.0
# 37           24.0          male      High School        78026.0
# 38           25.0          male         Bachelor        90785.0
# 39           23.0        female      High School        86811.0
# ...           ...           ...              ...            ...
# 44910        29.0          male         Bachelor        70997.0
# 44944        26.0          male        Associate        97590.0
# 44953        36.0          male           Master        71544.0
# 44962        23.0          male        Associate        89930.0
# 44984        24.0        female      High School        75941.0
#
#        person_emp_exp person_home_ownership  loan_amount        loan_intent  \
# 15                  5              MORTGAGE      30000.0  DEBTCONSOLIDATION
# 36                  0                  RENT      30000.0          EDUCATION
# 37                  3                  RENT      30000.0  DEBTCONSOLIDATION
# 38                  4                  RENT      30000.0    HOMEIMPROVEMENT
# 39                  0                  RENT      30000.0  DEBTCONSOLIDATION
# ...               ...                   ...          ...                ...
# 44910               6                  RENT      20000.0           PERSONAL
# 44944               7                  RENT      30000.0  DEBTCONSOLIDATION
# 44953              13                  RENT      10000.0          EDUCATION
# 44962               0              MORTGAGE      10000.0            VENTURE
# 44984               1                  RENT      20000.0            MEDICAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 15             10.65                 0.05                         3.0
# 36             18.39                 0.51                         2.0
# 37             14.54                 0.38                         3.0
# 38             16.89                 0.33                         4.0
# 39             11.01                 0.35                         4.0
# ...              ...                  ...                         ...
# 44910          13.28                 0.28                         5.0
# 44944           9.45                 0.31                         3.0
# 44953          10.85                 0.14                        15.0
# 44962           9.34                 0.11                         2.0
# 44984          14.85                 0.26                         4.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 15              670                            Yes            0
# 36              606                             No            1
# 37              582                             No            1
# 38              649                             No            1
# 39              602                             No            1
# ...             ...                            ...          ...
# 44910           676                             No            1
# 44944           666                             No            1
# 44953           576                             No            1
# 44962           657                             No            1
# 44984           592                             No            1
#
# [5126 rows x 14 columns]
